# %% [markdown]
# # Resultados e interpretabilidad
#
# sktime — útil pero solapado con lo que ya tienes
# sktime te daría clasificación de series temporales sobre las trayectorias de embeddings. El problema es que ya tienes ese rol cubierto: TabPFN captura el contexto temporal con la ventana deslizante, el T-GCN captura la evolución relacional, y el LSTM Baseline hace clasificación temporal directamente. Añadir un clasificador sktime sobre los embeddings sería un cuarto modelo supervisado que compite con el LSTM Baseline sin añadir nada conceptualmente distinto.
# Dónde sí encaja algo de esto de forma natural
# Hay un hueco real en tu pipeline: el LSTM Autoencoder va a producir un error de reconstrucción por banco y trimestre, pero no tienes ningún componente que agrupe bancos por similitud de trayectoria antes de la quiebra. DTW con clustering jerárquico sobre los embeddings de los bancos que sí quebraron (70 positivos en desarrollo) podría revelar si hay distintos patrones de deterioro, lo que tendría valor interpretativo directo para la memoria. Son solo 70 trayectorias, computacionalmente trivial.
# Resumen
# No los incorporaría al pipeline de predicción porque ya están cubiertos por componentes más potentes. Sí tiene sentido usar DTW + clustering jerárquico como análisis de interpretabilidad sobre los 70 bancos positivos del bloque de desarrollo, después de tener e_hybrid. Eso va en el notebook de evaluación e interpretabilidad, no en el pipeline principal.
